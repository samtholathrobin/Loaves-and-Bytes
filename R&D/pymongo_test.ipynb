# %%
from pymongo import MongoClient
from bson import ObjectId
import os
from dotenv import load_dotenv
from langchain.docstore.document import Document
from langchain_ollama import OllamaEmbeddings
import numpy as np
import faiss

# %%
load_dotenv()
URI = os.getenv("MONGODB_URI")
# Connect to MongoDB server
client = MongoClient(URI)

# %%
res_db = client["Res_Data"]
menu_collection = res_db["Res_menus"]

# %%
item = menu_collection.find_one({"_id":ObjectId('6854057e6dc04c1119f8adbf')})

# %%
from sentence_transformers import SentenceTransformer
embed_model = SentenceTransformer('all-mpnet-base-v2', cache_folder='./models/all-mpnet-base-v2')

def get_embedding(text):
    return embed_model.encode(text)

# %%
def generate_embeddings_for_menu(menu_id):
    res_db = client["Res_Data"]
    menu_collection = res_db["Res_menus"]
    item = menu_collection.find_one({"_id":ObjectId(menu_id)})
    updated_sections = []
    for section in item['menu']['sections']:
        updated_dishes = []
        for dish in section['dishes']:
            # Skip if embedding already exists
            if 'embedding' in dish:
                updated_dishes.append(dish)
                continue
            
            text = f"{dish['name']}. {dish['desc']}. Category: {section}."
            embedding = get_embedding(text)
            print(f"Embedding for {dish['name']}: {embedding.tolist()}")
            dish['embedding'] = embedding.tolist()
            
            updated_dishes.append(dish)

        section['dishes'] = updated_dishes
        updated_sections.append(section)

    # Push the full nested update back
    menu_collection.update_one(
        {'_id': ObjectId(menu_id)},
        {'$set': {'menu.sections': updated_sections}}
    )

# %%
generate_embeddings_for_menu('6854057e6dc04c1119f8adbf')

# %%
c=0
for section in item['menu']['sections']:
    print(section['name'])
    for dishes in section['dishes']:
        print(dishes['name'])
        if 'desc' in dishes:
            print(dishes['desc'])
        if 'price' in dishes:
            print(dishes['price'])
        c+=1
        print('------------------')
print(f'Total dishes: {c}')
# Out:
# Appetizers
# Loaded Nachos
# Crispy tortilla chips topped with melted cheese, jalapeños, sour cream, and salsa
# 7.0
# ------------------
# Hummus & Pita Platter
# Creamy hummus served with warm pita bread and fresh vegetable sticks
# 8.0
# ------------------
# Sweet Potato Fries
# Crispy sweet potato fries served with a tangy honey mustard dip
# 8.0
# ------------------
# Buffalo Wings
# Juicy chicken wings tossed in a tangy buffalo sauce, served with ranch or blue cheese dressing
# 8.0
# ------------------
# Garlic Bread
# Toasted baguette slices topped with garlic butter and herbs, served with marinara sauce
# 5.0
# ------------------
# Chicken Tenders
# Crispy breaded chicken strips served with honey mustard or barbecue sauce
# 7.0
# ------------------
# Mozzarella Sticks
# Golden-fried mozzarella cheese sticks served with a side of marinara sauce
# 5.0
# ------------------
# Bruschetta
# Grilled bread topped with diced tomatoes, garlic, basil, and a drizzle of balsamic glaze
# 8.0
# ------------------
# Onion Rings
# Thick-cut onions battered and fried to a golden crisp, served with a tangy dipping sauce
# 5.0
# ------------------
# Deviled Eggs
# Hard-boiled eggs halved and filled with a creamy yolk mix seasoned with mustard and paprika
# 6.0
# ------------------
# Main Dishes
# Bistro Burger
# Juicy beef patty, cheddar cheese, lettuce, tomato, and onion on a brioche bun. Served with fries
# 10.0
# ------------------
# Veggie Wrap
# A whole-wheat wrap filled with roasted vegetables, hummus, and mixed greens
# 10.0
# ------------------
# Classic Eggs
# Poached eggs and Canadian bacon on an English muffin, topped with hollandaise sauce
# 12.0
# ------------------
# Chicken Caesar Salad
# Grilled chicken breast served on crisp romaine lettuce with Caesar dressing and croutons
# 15.0
# ------------------
# Margherita Pizza
# Thin crust topped with fresh mozzarella, tomatoes, basil, and a drizzle of olive oil
# 12.0
# ------------------
# BBQ Ribs
# Tender pork ribs smothered in smoky barbecue sauce, served with coleslaw and cornbread
# 20.0
# ------------------
# Fish and Chips
# Crispy battered cod served with golden fries, tartar sauce, and a side of mushy peas
# 15.0
# ------------------
# Beverages
# Cappuccino
# Rich espresso blended with steamed milk and topped with a light, foamy milk froth
# 4.5
# ------------------
# Americano
# Bold espresso diluted with hot water for a smooth, robust flavor
# 4.0
# ------------------
# Mocha
# A rich combination of espresso, chocolate, and steamed milk with cream
# 4.75
# ------------------
# Hot Chocolate
# Creamy hot cocoa topped with whipped cream and a sprinkle of chocolate
# 4.25
# ------------------
# Chai Latte
# A warm and spiced blend of black tea, steamed milk, and exotic spices like cinnamon and cardamom
# 4.75
# ------------------
# Espresso
# A strong and concentrated shot of coffee with a rich, bold flavor and golden crema
# 3.5
# ------------------
# Mango Smoothie
# A tropical blend of ripe mangoes, yogurt, and a touch of honey, served over ice
# 5.5
# ------------------
# Berry Lemonade
# Refreshing lemonade infused with mixed berries and served over ice
# 5.25
# ------------------
# Rose Lemonade
# A floral twist on classic lemonade, infused with rose essence and served over ice
# 5.0
# ------------------
# Iced Latte
# Chilled espresso poured over ice with cold milk for a smooth, refreshing drink
# 4.75
# ------------------
# Matcha Latte
# Chilled matcha green tea blended with milk and served over ice for a creamy taste
# 5.0
# ------------------
# Peach Iced Tea
# Black tea infused with ripe peach flavor, served over ice and a slice of lemon
# 4.25
# ------------------
# Iced Mocha
# Chilled espresso blended with milk, sweet chocolate syrup, and ice
# 5.25
# ------------------
# Vanilla Frappe
# Blended ice drink with vanilla milk and espresso, topped with whipped cream
# 5.75
# ------------------
# Salted Caramel
# Creamy vanilla ice cream blended with salted caramel and topped with whipped cream
# 6.0
# ------------------
# Desserts
# Chocolate Lava Cake
# Warm chocolate cake with a molten chocolate center, served with vanilla ice cream
# 8.5
# ------------------
# Classic Cheesecake
# Rich and creamy cheesecake with a buttery graham cracker crust
# 7.0
# ------------------
# Vegan Brownie
# Decadent chocolate brownie made without dairy or eggs
# 5.5
# ------------------
# Fruit Tart
# Sweet pastry crust filled with custard and topped with fresh seasonal fruits
# 9.0
# ------------------
# Banana Split
# A trio of ice cream scoops served with banana slices, chocolate sauce, and whipped cream
# 6.75
# ------------------
# Carrot Cake
# Moist spiced carrot cake topped with a smooth cream cheese frosting
# 6.0
# ------------------
# Lemon Sorbet
# Refreshing lemon sorbet made with real citrus juice
# 4.5
# ------------------
# Peanut Butter Pie
# Creamy peanut butter filling in a chocolate cookie crust, topped with whipped cream
# 7.75
# ------------------
# Molten White Chocolate Bomb
# White chocolate sphere melted tableside to reveal cake and berries inside
# 10.0
# ------------------
# Coconut Macaroons
# Chewy coconut cookies, lightly toasted and drizzled with dark chocolate
# 3.75
# ------------------
# Special Dishes
# Grilled Shrimp Tacos
# Soft corn tortillas filled with grilled shrimp, avocado, cilantro and lime cream with a drizzle of ranch sauce served with guacamole
# 25.0
# ------------------
# Beef Steak Frites
# Tender grilled beef steak served with organic garlic herb butter and curly crispy fries
# 30.0
# ------------------
# Total dishes: 44

# %%
item = menu_collection.find_one({"_id":ObjectId('6854057e6dc04c1119f8adbf')})
for section in item['menu']['sections']:
    for dish in section['dishes']:
        if 'embedding' in dish:
            print(f"{dish['name']}: {dish['embedding'][:5]}...")  # Print first 5 values of the embedding
        else:
            print(f"{dish['name']}: No embedding found. Please generate embeddings first.")

# %%
import numpy as np

dish_records = []
menu_doc = menu_collection.find_one({"_id": ObjectId('6854057e6dc04c1119f8adbf')})

# Flatten dishes and collect embeddings
for section in menu_doc["menu"]["sections"]:
    for dish in section["dishes"]:
        if "embedding" in dish:
            dish_records.append({
                "name": dish["name"],
                "description": dish.get("desc", ""),
                "section": section["name"],
                "price": dish["price"],
                "tags": dish.get("tags", []),
                "embedding": np.array(dish["embedding"], dtype="float32")
            })

# %%
import faiss
dim = len(dish_records[0]["embedding"])
index = faiss.IndexFlatL2(dim)

# Add embeddings to index
embeddings = np.array([d["embedding"] for d in dish_records])
index.add(embeddings)

# %%
model = SentenceTransformer("all-mpnet-base-v2", cache_folder='./models/bge-small-en-v1.5')  # Or your lightweight model

# Define user query
query_text = "crispy chicken starter with sauce"

# Encode query
query_vector = model.encode(query_text).astype("float32").reshape(1, -1)

# Search FAISS index
k = 10
distances, indices = index.search(query_vector, k)

# Get top-k results
results = [dish_records[i] for i in indices[0]]
for result in results:
    print(f'Name: {result["name"]}, Section: {result["section"]}, Price: {result["price"]}, Tags: {result["tags"]} Description: {result["description"]}')
# Out:
# Name: Chicken Tenders, Section: Appetizers, Price: 7.0, Tags: ['meat', 'gluten'] Description: Crispy breaded chicken strips served with honey mustard or barbecue sauce
# Name: Hummus & Pita Platter, Section: Appetizers, Price: 8.0, Tags: ['vegan', 'gluten'] Description: Creamy hummus served with warm pita bread and fresh vegetable sticks
# Name: Chicken Caesar Salad, Section: Main Dishes, Price: 15.0, Tags: ['meat', 'dairy', 'gluten'] Description: Grilled chicken breast served on crisp romaine lettuce with Caesar dressing and croutons
# Name: Buffalo Wings, Section: Appetizers, Price: 8.0, Tags: ['spicy', 'meat', 'dairy'] Description: Juicy chicken wings tossed in a tangy buffalo sauce, served with ranch or blue cheese dressing
# Name: Bistro Burger, Section: Main Dishes, Price: 10.0, Tags: ['meat', 'gluten', 'dairy'] Description: Juicy beef patty, cheddar cheese, lettuce, tomato, and onion on a brioche bun. Served with fries
# Name: Beef Steak Frites, Section: Special Dishes, Price: 30.0, Tags: ['meat', 'dairy', 'gluten'] Description: Tender grilled beef steak served with organic garlic herb butter and curly crispy fries
# Name: Grilled Shrimp Tacos, Section: Special Dishes, Price: 25.0, Tags: ['fish', 'dairy', 'gluten', 'spicy'] Description: Soft corn tortillas filled with grilled shrimp, avocado, cilantro and lime cream with a drizzle of ranch sauce served with guacamole
# Name: BBQ Ribs, Section: Main Dishes, Price: 20.0, Tags: ['meat', 'gluten'] Description: Tender pork ribs smothered in smoky barbecue sauce, served with coleslaw and cornbread
# Name: Classic Eggs, Section: Main Dishes, Price: 12.0, Tags: ['egg', 'meat', 'gluten', 'dairy'] Description: Poached eggs and Canadian bacon on an English muffin, topped with hollandaise sauce
# Name: Onion Rings, Section: Appetizers, Price: 5.0, Tags: ['vegetarian', 'gluten'] Description: Thick-cut onions battered and fried to a golden crisp, served with a tangy dipping sauce

# %%
def search_menu(query_text, menu_id, k=10, threshold = 0.2):
    dish_records = []
    menu_doc = menu_collection.find_one({"_id": ObjectId(menu_id)})

    # Flatten dishes and collect embeddings
    for section in menu_doc["menu"]["sections"]:
        for dish in section["dishes"]:
            if "embedding" in dish:
                dish_records.append({
                    "name": dish["name"],
                    "description": dish.get("desc", ""),
                    "section": section["name"],
                    "price": dish["price"],
                    "tags": dish.get("tags", []),
                    "embedding": np.array(dish["embedding"], dtype="float32")
                })

    dim = len(dish_records[0]["embedding"])
    index = faiss.IndexFlatL2(dim)
    # Add embeddings to index
    embeddings = np.array([d["embedding"] for d in dish_records])
    index.add(embeddings)

    model = SentenceTransformer("all-mpnet-base-v2") 
    query_vector = model.encode(query_text).astype("float32").reshape(1, -1)
    distances, indices = index.search(query_vector, k)
    similarities = 1 - distances[0]  # Convert distance to similarity

    results = []
    for i, sim in zip(indices[0], similarities):
        if sim >= threshold:
            doc = dish_records[i]
            print(sim, ' - ', doc['name'], doc['section'], doc['price'], doc['tags'], doc['description'])
            doc.pop('embedding', None)
            results.append(doc)
    return results

# %%
out = search_menu(query_text = "cool drinks" , menu_id = '6854057e6dc04c1119f8adbf', k=10, threshold = -1)
# Out:
# -0.16926658  -  Rose Lemonade Beverages 5.0 ['cold', 'vegan', 'gluten-free'] A floral twist on classic lemonade, infused with rose essence and served over ice
# -0.18399274  -  Peach Iced Tea Beverages 4.25 ['cold', 'caffeine', 'vegan', 'gluten-free'] Black tea infused with ripe peach flavor, served over ice and a slice of lemon
# -0.19971251  -  Berry Lemonade Beverages 5.25 ['cold', 'vegan', 'gluten-free'] Refreshing lemonade infused with mixed berries and served over ice
# -0.20209372  -  Iced Latte Beverages 4.75 ['cold', 'dairy', 'caffeine', 'gluten-free'] Chilled espresso poured over ice with cold milk for a smooth, refreshing drink
# -0.24149108  -  Iced Mocha Beverages 5.25 ['cold', 'dairy', 'caffeine', 'gluten-free'] Chilled espresso blended with milk, sweet chocolate syrup, and ice
# -0.29977608  -  Matcha Latte Beverages 5.0 ['cold', 'dairy', 'caffeine', 'gluten-free'] Chilled matcha green tea blended with milk and served over ice for a creamy taste
# -0.30542064  -  Espresso Beverages 3.5 ['hot', 'caffeine', 'gluten-free', 'vegan'] A strong and concentrated shot of coffee with a rich, bold flavor and golden crema
# -0.30937767  -  Vanilla Frappe Beverages 5.75 ['cold', 'dairy', 'caffeine', 'gluten-free'] Blended ice drink with vanilla milk and espresso, topped with whipped cream
# -0.3443495  -  Mango Smoothie Beverages 5.5 ['cold', 'dairy', 'gluten-free'] A tropical blend of ripe mangoes, yogurt, and a touch of honey, served over ice
# -0.35508943  -  Americano Beverages 4.0 ['hot', 'caffeine', 'gluten-free', 'vegan'] Bold espresso diluted with hot water for a smooth, robust flavor
